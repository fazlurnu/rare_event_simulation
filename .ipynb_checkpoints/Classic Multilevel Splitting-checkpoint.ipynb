# %%
import numpy as np
import matplotlib.pyplot as plt

x0 = 1
a = 0
M = 12
mu = -1

# %%
def analytic_probability(a:float, x0: float, M: float, mu: float) -> float:
    return np.exp(mu * (M - x0)) * (np.sinh((x0-a)*np.abs(mu)) / np.sinh((M-a)*np.abs(mu)))
                                    
true_prob = analytic_probability(a, x0, M, mu)
print(true_prob)
# Out:
# 2.4119546385320695e-10

# %%
def simulate_trajectory_with_path(start_pos, mu, M, dt=0.01):
    """Simulates trajectory and returns both max and path"""
    x = start_pos
    trajectory = [x]
    max_x = x
    while x > 0:
        dx = mu * dt + np.sqrt(dt) * np.random.randn()
        x += dx
        trajectory.append(x)
        max_x = max(max_x, x)
        if max_x >= M:
            break  # Early exit if M is reached
    return max_x, trajectory

def classic_multilevel_splitting(n, x0, M, mu, num_levels=8):
    """Classic multilevel splitting algorithm with probability calculation"""
    levels = np.linspace(x0, M, num_levels + 1)[1:]  # Split M into num_levels steps
    particles = [{'max': None, 'trajectory': None} for _ in range(n)]
    successful_trajectory = None
    probability = 1.0  # Initialize probability

    # Initialize particles
    for i in range(n):
        max_x, trajectory = simulate_trajectory_with_path(x0, mu, M)
        particles[i]['max'] = max_x
        particles[i]['trajectory'] = trajectory
        if max_x >= M:
            return trajectory, 1.0  # Return immediately if found, probability is 1

    for i in range(len(levels) - 1):
        level = levels[i]
        next_M = levels[i+1]
        print(f"Start pos: {level:.2f}, Intermediate M: {next_M:.2f}")
        # Resample particles that reach the current level
        max_values = np.array([p['max'] for p in particles])
        survivors = [p for p in particles if p['max'] >= level]

        if len(survivors) == 0:
            break  # No particles reached the current level

        # Estimate conditional probability for this level
        conditional_prob = len(survivors) / n
        print(f"Intermediate prob: {conditional_prob:.2f}")
        probability *= conditional_prob

        # Resample non-survivors
        for i in range(n):
            if particles[i]['max'] < level:
                parent = np.random.choice(survivors)
                parent_traj = parent['trajectory']
                
                # Find split point where trajectory first reaches level
                split_idx = next((i for i, x in enumerate(parent_traj) if x >= level), len(parent_traj)-1)
                start_pos = parent_traj[split_idx]
                
                # Simulate new trajectory from split point
                new_max, new_traj = simulate_trajectory_with_path(start_pos, mu, next_M)
                
                # Combine trajectories
                combined_traj = parent_traj[:split_idx+1] + new_traj[1:]
                particles[i]['max'] = max(new_max, level)
                particles[i]['trajectory'] = combined_traj
                
                if new_max >= M:
                    return combined_traj, probability

    # If no trajectory reaches M, return the one with the highest max and the estimated probability
    max_particle = max(particles, key=lambda p: p['max'])
    return max_particle['trajectory'], probability

# Parameters
n = 5000

# Get trajectory and probability
trajectory, probability = classic_multilevel_splitting(n, x0, M, mu, num_levels=12)
time_points = np.arange(len(trajectory)) * 0.01

# Print the probability
print(f"Estimated probability of reaching M = {M}: {probability:.6e}")

# Plot the trajectory
plt.figure(figsize=(10, 6))
plt.plot(time_points, trajectory)
plt.axhline(M, color='r', linestyle='--', label=f'Threshold M = {M}')
plt.xlabel('Time')
plt.ylabel('Position')
plt.title('Classic Multilevel Splitting-Generated Trajectory Reaching M')
plt.legend()
plt.show()
# Out:
# Start pos: 1.92, Intermediate M: 2.83
# 0.1282
# Start pos: 2.83, Intermediate M: 3.75
# 0.1576
# Start pos: 3.75, Intermediate M: 4.67
# 0.1314
# Start pos: 4.67, Intermediate M: 5.58
# 0.141
# Start pos: 5.58, Intermediate M: 6.50
# 0.1336
# Start pos: 6.50, Intermediate M: 7.42
# 0.1468
# Start pos: 7.42, Intermediate M: 8.33
# 0.1406
# Start pos: 8.33, Intermediate M: 9.25
# 0.1314
# Start pos: 9.25, Intermediate M: 10.17
# 0.1426
# Start pos: 10.17, Intermediate M: 11.08
# 0.1394
# Start pos: 11.08, Intermediate M: 12.00
# 0.1362
# Estimated probability of reaching M = 12: 3.672242e-10
